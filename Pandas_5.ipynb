# %%
import pandas as pd

# %%
# ******* Dataframe ******* #

Details={
    "Name"    :["Sinchan","Doraemon","Tom","Jerry"],
    "Channel" :["hungama","Disney","CN","CN"],
    "Email"  :["chan@gmail.com","doraemon@gmail.com","tom@gmail.com","jerry@gmail.com"]
}

# %%
df = pd.DataFrame(Details)

# %%
df
# Out:
#        Name  Channel               Email
# 0   Sinchan  hungama      chan@gmail.com
# 1  Doraemon   Disney  doraemon@gmail.com
# 2       Tom       CN       tom@gmail.com
# 3     Jerry       CN     jerry@gmail.com

# %%
df['Name'] + '-->' + df ['Email']
# Out:
# 0         Sinchan-->chan@gmail.com
# 1    Doraemon-->doraemon@gmail.com
# 2              Tom-->tom@gmail.com
# 3          Jerry-->jerry@gmail.com
# dtype: object

# %%
df['Name_channel'] = df['Name']+'@'+df['Channel']

# %%
df
# Out:
#        Name  Channel               Email     Name_channel
# 0   Sinchan  hungama      chan@gmail.com  Sinchan@hungama
# 1  Doraemon   Disney  doraemon@gmail.com  Doraemon@Disney
# 2       Tom       CN       tom@gmail.com           Tom@CN
# 3     Jerry       CN     jerry@gmail.com         Jerry@CN

# %%
df['Email'].str.split('@',expand=True)
# Out:
#           0          1
# 0      chan  gmail.com
# 1  doraemon  gmail.com
# 2       tom  gmail.com
# 3     jerry  gmail.com

# %%
df[['name_mail','email_type']] = df['Email'].str.split('@',expand=True)
df
# Out:
#        Name  Channel               Email     Name_channel name_mail email_type
# 0   Sinchan  hungama      chan@gmail.com  Sinchan@hungama      chan  gmail.com
# 1  Doraemon   Disney  doraemon@gmail.com  Doraemon@Disney  doraemon  gmail.com
# 2       Tom       CN       tom@gmail.com           Tom@CN       tom  gmail.com
# 3     Jerry       CN     jerry@gmail.com         Jerry@CN     jerry  gmail.com

# %%
df.loc[len(df.index)] = ['Mottu', 'Nick', ' mottu@gmail.com','Mottu@Nick','mottu','gmail.com']
df
# Out:
#        Name  Channel               Email     Name_channel name_mail email_type
# 0   Sinchan  hungama      chan@gmail.com  Sinchan@hungama      chan  gmail.com
# 1  Doraemon   Disney  doraemon@gmail.com  Doraemon@Disney  doraemon  gmail.com
# 2       Tom       CN       tom@gmail.com           Tom@CN       tom  gmail.com
# 3     Jerry       CN     jerry@gmail.com         Jerry@CN     jerry  gmail.com
# 4     Mottu     Nick     mottu@gmail.com       Mottu@Nick     mottu  gmail.com

# %%
df._append({'Name':'Pattlu'},ignore_index=True)
# Out:
#        Name  Channel               Email     Name_channel name_mail email_type
# 0   Sinchan  hungama      chan@gmail.com  Sinchan@hungama      chan  gmail.com
# 1  Doraemon   Disney  doraemon@gmail.com  Doraemon@Disney  doraemon  gmail.com
# 2       Tom       CN       tom@gmail.com           Tom@CN       tom  gmail.com
# 3     Jerry       CN     jerry@gmail.com         Jerry@CN     jerry  gmail.com
# 4     Mottu     Nick     mottu@gmail.com       Mottu@Nick     mottu  gmail.com
# 5    Pattlu      NaN                 NaN              NaN       NaN        NaN

# %%
Details_2 = {
    'Name':['Chotta','Bheem'],
    'Language':['Hindi','Tamil'],
    'Email':['chotta@pogo.com','bheem@pogo.com']
}

# %%
df_2 = pd.DataFrame(Details_2)
df_2
# Out:
#      Name Language            Email
# 0  Chotta    Hindi  chotta@pogo.com
# 1   Bheem    Tamil   bheem@pogo.com

# %%
df._append(df_2,ignore_index=True,sort=True)
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 5      NaN     chotta@pogo.com    Hindi    Chotta              NaN        NaN
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 0      chan
# 1  doraemon
# 2       tom
# 3     jerry
# 4     mottu
# 5       NaN
# 6       NaN

# %%
df
# Out:
#        Name  Channel               Email     Name_channel name_mail email_type
# 0   Sinchan  hungama      chan@gmail.com  Sinchan@hungama      chan  gmail.com
# 1  Doraemon   Disney  doraemon@gmail.com  Doraemon@Disney  doraemon  gmail.com
# 2       Tom       CN       tom@gmail.com           Tom@CN       tom  gmail.com
# 3     Jerry       CN     jerry@gmail.com         Jerry@CN     jerry  gmail.com
# 4     Mottu     Nick     mottu@gmail.com       Mottu@Nick     mottu  gmail.com

# %%
df=df._append(df_2,ignore_index=True,sort=True)
df
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 5      NaN     chotta@pogo.com    Hindi    Chotta              NaN        NaN
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 0      chan
# 1  doraemon
# 2       tom
# 3     jerry
# 4     mottu
# 5       NaN
# 6       NaN

# %%
df.drop(5,inplace=True)

# %%
df
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 0      chan
# 1  doraemon
# 2       tom
# 3     jerry
# 4     mottu
# 6       NaN

# %%
######## removing single row by condition

df.drop(index = df[df['Language']=='Tamil'].index)

#-----> Or
#  filt = df['Language']=='Tamil'
#  df.drop(index = df[filt].index)
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
#
#   name_mail
# 0      chan
# 1  doraemon
# 2       tom
# 3     jerry
# 4     mottu

# %%
####### removing single column

df.drop(['Language'], axis = 1)
# Out:
#    Channel               Email      Name     Name_channel email_type name_mail
# 0  hungama      chan@gmail.com   Sinchan  Sinchan@hungama  gmail.com      chan
# 1   Disney  doraemon@gmail.com  Doraemon  Doraemon@Disney  gmail.com  doraemon
# 2       CN       tom@gmail.com       Tom           Tom@CN  gmail.com       tom
# 3       CN     jerry@gmail.com     Jerry         Jerry@CN  gmail.com     jerry
# 4     Nick     mottu@gmail.com     Mottu       Mottu@Nick  gmail.com     mottu
# 6      NaN      bheem@pogo.com     Bheem              NaN        NaN       NaN

# %%
df.sort_values(by= 'Channel' , ascending = False)
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 0      chan
# 4     mottu
# 1  doraemon
# 2       tom
# 3     jerry
# 6       NaN

# %%
df.sort_values(by= ['Name', 'Channel' ], ascending = [False ,True],inplace =True)
df
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 2       tom
# 0      chan
# 4     mottu
# 3     jerry
# 1  doraemon
# 6       NaN

# %%
df.sort_index()
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail
# 0      chan
# 1  doraemon
# 2       tom
# 3     jerry
# 4     mottu
# 6       NaN

# %%
df['Channel'].sort_values()
# Out:
# 2         CN
# 3         CN
# 1     Disney
# 4       Nick
# 0    hungama
# 6        NaN
# Name: Channel, dtype: object

# %%
numeric_data = df.select_dtypes(include='number')

# %%
median_values = numeric_data.median()
median_values
# Out:
# Series([], dtype: float64)

# %%
df['Values'] = [1,2,3,4,5,6]

# %%
df
# Out:
#    Channel               Email Language      Name     Name_channel email_type  \
# 2       CN       tom@gmail.com      NaN       Tom           Tom@CN  gmail.com
# 0  hungama      chan@gmail.com      NaN   Sinchan  Sinchan@hungama  gmail.com
# 4     Nick     mottu@gmail.com      NaN     Mottu       Mottu@Nick  gmail.com
# 3       CN     jerry@gmail.com      NaN     Jerry         Jerry@CN  gmail.com
# 1   Disney  doraemon@gmail.com      NaN  Doraemon  Doraemon@Disney  gmail.com
# 6      NaN      bheem@pogo.com    Tamil     Bheem              NaN        NaN
#
#   name_mail  Values
# 2       tom       1
# 0      chan       2
# 4     mottu       3
# 3     jerry       4
# 1  doraemon       5
# 6       NaN       6

# %%
numeric_data = df.select_dtypes(include='number')

# %%
median_values = numeric_data.median()
median_values
# Out:
# Values    3.5
# dtype: float64
