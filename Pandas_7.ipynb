# %%
import pandas as pd

# %%
schema_df = pd.read_csv(r"datas\survey_results_schema.csv")
df = pd.read_csv(r"datas\survey_results_public.csv")

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
schema_df.columns
# Out:
# Index(['qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
schema_df.set_index('qid',inplace=True,)

# %%
schema_df
# Out:
#               qname                                           question  \
# qid
# QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12      MetaInfo                                  Browser Meta Info
# QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# QID312         Q120
# QID1             S1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# QID289  Knowledge_7  Waiting on answers to questions often causes i...
# QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# QID290  Frequency_1  Needing help from people outside of your immed...
# QID290  Frequency_2  Interacting with people outside of your immedi...
# QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# ...

# %%
schema_df.loc['QID16','question']
# Out:
# '<div><span style="font-size:19px;"><strong>Hello world! </strong></span></div>\n\n<div> </div>\n\n<div>Thank you for taking the 2023 Stack Overflow Developer Survey, the longest running survey of software developers (and anyone else who codes!) on Earth. </div>\n\n<div> </div>\n\n<div>There are seven sections in this survey. The 2nd, 3rd, 4th and 5th sections will appear in a random order.</div><div><br></div>\n\n<div>   1. Basic Information</div>\n\n<div>   2. Education, Work, and Career</div>\n\n<div>   3. Technology and Tech Culture</div>\n\n<div>   4. Stack Overflow Usage + Community</div>\n\n<div>   5. Artificial Intelligence </div>\n\n<div>   6. Professional Developer Series (Optional)</div><div>   7. Final Questions</div>\n\n<div> \n<div>Most questions in this survey are optional. Required questions are marked with *. This anonymous survey will take about 15 minutes to complete. We encourage you to complete it in one sitting.</div><div><br></div>\n</div>\n\n<div><strong>If yo
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: count, dtype: int64

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 25-34 years old       0.372791
# 35-44 years old       0.230221
# 18-24 years old       0.201056
# 45-54 years old       0.093447
# Under 18 years old    0.046286
# 55-64 years old       0.038034
# 65 years or older     0.013130
# Prefer not to say     0.005035
# Name: proportion, dtype: float64

# %% [markdown]
# Groupby ==> Splitting , Applyng function , combine results

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9676\421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: count, dtype: int64

# %%
country_grp['Age'].value_counts().loc['India']
# Out:
# Age
# 18-24 years old       2296
# 25-34 years old       2289
# 35-44 years old        512
# Under 18 years old     378
# 45-54 years old        107
# 55-64 years old         20
# Prefer not to say       19
# 65 years or older        4
# Name: count, dtype: int64

# %%
#### By using Normalize it gives in percentage

country_grp['Age'].value_counts(normalize= True).loc['India']
# Out:
# Age
# 18-24 years old       0.408178
# 25-34 years old       0.406933
# 35-44 years old       0.091022
# Under 18 years old    0.067200
# 45-54 years old       0.019022
# 55-64 years old       0.003556
# Prefer not to say     0.003378
# 65 years or older     0.000711
# Name: proportion, dtype: float64

# %%
country_grp['Age'].value_counts().loc['India'].median()
# Out:
# 242.5

# %%
#### Another way by using filter ####

country_filt = df['Country'] == 'India'
df.loc[country_filt]['Age'].value_counts()
# Out:
# Age
# 18-24 years old       2296
# 25-34 years old       2289
# 35-44 years old        512
# Under 18 years old     378
# 45-54 years old        107
# 55-64 years old         20
# Prefer not to say       19
# 65 years or older        4
# Name: count, dtype: int64

# %%
country_grp['CompTotal'].value_counts().loc['India'].median()
# Out:
# 1.0

# %%
country_grp ['CompTotal'].median().loc['India']
# Out:
# 1450000.0

# %%
country_grp ['CompTotal'].agg(['median','mean'])
# Out:
#                                            median          mean
# Country
# Afghanistan                               62333.0  6.666117e+07
# Albania                                  104850.0  1.185178e+06
# Algeria                                  540000.0  7.836667e+05
# Andorra                                  120000.0  1.562473e+09
# Angola                                  2600000.0  2.600000e+06
# ...                                           ...           ...
# Venezuela, Bolivarian Republic of...      14400.0  2.482463e+04
# Viet Nam                              200000000.0  3.287808e+08
# Yemen                                      9000.0  2.252071e+06
# Zambia                                    84000.0  1.507400e+05
# Zimbabwe                                  12500.0  2.674000e+04
#
# [185 rows x 2 columns]

# %%
country_grp ['CompTotal'].agg(['median','mean']).loc['India']
# Out:
# median    1.450000e+06
# mean      1.205815e+07
# Name: India, dtype: float64

# %%
country_filt = df['Country'] == 'India'
df.loc[country_filt]['LanguageHaveWorkedWith']
# Out:
# 9        HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 66                                       Java;Scala;SQL
# 78                                JavaScript;TypeScript
# 82                                                  C++
# 85                   Assembly;C;C++;Java;JavaScript;SQL
#                               ...
# 89119                   Dart;HTML/CSS;JavaScript;Python
# 89121                                        Python;SQL
# 89164                Go;HTML/CSS;Java;JavaScript;Python
# 89165               C;C#;C++;Java;JavaScript;TypeScript
# 89167               Dart;HTML/CSS;JavaScript;TypeScript
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
country_filt = df['Country'] == 'India'
df.loc[country_filt]['LanguageHaveWorkedWith'].str.contains('Java')
# Out:
# 9         True
# 66        True
# 78        True
# 82       False
# 85        True
#          ...
# 89119     True
# 89121    False
# 89164     True
# 89165     True
# 89167     True
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
country_filt = df['Country'] == 'India'
df.loc[country_filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 2793

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_resp = df['Country'].value_counts()
country_resp
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_use_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
country_use_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
pandas_df = pd.concat([country_resp , country_use_python], axis = 'columns', sort=False)
pandas_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Saint Kitts and Nevis                                   1
# Marshall Islands                                        1
# Samoa                                                   1
# Central African Republic                                1
# San Marino                                              1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
pandas_df.rename(columns = {'count':'No.of.Resp', 'LanguageHaveWorkedWith' : 'Known_Python'},inplace=True)
pandas_df
# Out:
#                                                     No.of.Resp  Known_Python
# Country
# United States of America                                 18647         10062
# Germany                                                   7328          3686
# India                                                     5625          2793
# United Kingdom of Great Britain and Northern Ir...        5552          2752
# Canada                                                    3507          1784
# ...                                                        ...           ...
# Saint Kitts and Nevis                                        1             0
# Marshall Islands                                             1             0
# Samoa                                                        1             1
# Central African Republic                                     1             0
# San Marino                                                   1             1
#
# [185 rows x 2 columns]

# %%
pandas_df['pct_know_python'] = (pandas_df['Known_Python']/pandas_df['No.of.Resp'])*100
pandas_df
# Out:
#                                                     No.of.Resp  Known_Python  \
# Country
# United States of America                                 18647         10062
# Germany                                                   7328          3686
# India                                                     5625          2793
# United Kingdom of Great Britain and Northern Ir...        5552          2752
# Canada                                                    3507          1784
# ...                                                        ...           ...
# Saint Kitts and Nevis                                        1             0
# Marshall Islands                                             1             0
# Samoa                                                        1             1
# Central African Republic                                     1             0
# San Marino                                                   1             1
#
# ...

# %%
pandas_df.sort_values(by='pct_know_python',ascending=False)
# Out:
#                                        No.of.Resp  Known_Python  \
# Country
# San Marino                                      1             1
# North Korea                                     4             4
# Samoa                                           1             1
# Liechtenstein                                   1             1
# Grenada                                         1             1
# ...                                           ...           ...
# Guinea                                          2             0
# Monaco                                          2             0
# Bahamas                                         2             0
# Niger                                           4             0
# Democratic People's Republic of Korea           2             0
#
#                                        pct_know_python
# Country
# San Marino                                       100.0
# North Korea                                      100.0
# ...

# %%
pandas_df.loc['India']
# Out:
# No.of.Resp         5625.000000
# Known_Python       2793.000000
# pct_know_python      49.653333
# Name: India, dtype: float64

# %%
df['YearsCode'].head(10)
# Out:
# 0    NaN
# 1     18
# 2     27
# 3     12
# 4      6
# 5     21
# 6      4
# 7      5
# 8     20
# 9      6
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] .unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9676\2593874309.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['YearsCode'].replace('Less than 1 year',0,inplace=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9676\2593874309.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['YearsCode'] = df['YearsCode'] .astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 13.966855378281009

# %%
df['YearsCode'].median()
# Out:
# 11.0
